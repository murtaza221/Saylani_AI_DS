# %% [markdown]
# ## A list of Dictionaries

# %%
alistofdic = [  {'items':[1,2,3,4], 
                 'price':[11,22,33,44]},
                {'students':["a","b","c","d"], 
                 'rollno':[123,345,444,323]},
              ]

#accessing elements
alistofdic[1]['students'][2]
# Out:
# 'c'

# %%
for item in alistofdic:
    print("yes")
# Out:
# yes
# yes

# %%
for mem in range(len(alistofdic)):
  if 'rollno' in alistofdic[mem]:
    for rn in alistofdic[mem]['rollno']:
      print(rn)


for mem in range(len(alistofdic)):
  if 'students' in alistofdic[mem]:
    for rn in alistofdic[mem]['students']:
      print(rn)
# Out:
# 123
# 345
# 444
# 323
# a
# b
# c
# d

# %%
# book Example pg 142
# aliens.py

alien0 = {'color':'green', 'points':5}
alien1 = {'color':'yellow', 'points':10}
alien2 = {'color':'red', 'points':15}

aliens = [alien0,alien1,alien2]

for alien in aliens:
  print(alien)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'yellow', 'points': 10}
# {'color': 'red', 'points': 15}

# %%
#example pg 142
# Make an empty list for storing aliens.
aliens = []
# Make 30 green aliens.
for alien_number in range(30):
   new_alien = {'color': 'green', 'points': alien_number, 'speed': 'slow'}
   aliens.append(new_alien)

# Show the first 5 aliens:
for alien in aliens[:5]:
   print(alien)
print("...")
# Show how many aliens have been created.
print("Total number of aliens: " + str(len(aliens)))
# Out:
# {'color': 'green', 'points': 0, 'speed': 'slow'}
# {'color': 'green', 'points': 1, 'speed': 'slow'}
# {'color': 'green', 'points': 2, 'speed': 'slow'}
# {'color': 'green', 'points': 3, 'speed': 'slow'}
# {'color': 'green', 'points': 4, 'speed': 'slow'}
# ...
# Total number of aliens: 30

# %%
for alien in aliens[0:3]:
 if alien['color'] == 'green':
   alien['color'] = 'yellow'
   alien['speed'] = 'medium'
   alien['points'] = 10
 elif alien['color'] == 'yellow':
   alien['color'] = 'red'
   alien['speed'] = 'fast'
   alien['points'] = 15
   
aliens
# Out:
# [{'color': 'red', 'points': 15, 'speed': 'fast'},
#  {'color': 'red', 'points': 15, 'speed': 'fast'},
#  {'color': 'red', 'points': 15, 'speed': 'fast'},
#  {'color': 'green', 'points': 3, 'speed': 'slow'},
#  {'color': 'green', 'points': 4, 'speed': 'slow'},
#  {'color': 'green', 'points': 5, 'speed': 'slow'},
#  {'color': 'green', 'points': 6, 'speed': 'slow'},
#  {'color': 'green', 'points': 7, 'speed': 'slow'},
#  {'color': 'green', 'points': 8, 'speed': 'slow'},
#  {'color': 'green', 'points': 9, 'speed': 'slow'},
#  {'color': 'green', 'points': 10, 'speed': 'slow'},
#  {'color': 'green', 'points': 11, 'speed': 'slow'},
#  {'color': 'green', 'points': 12, 'speed': 'slow'},
#  {'color': 'green', 'points': 13, 'speed': 'slow'},
#  {'color': 'green', 'points': 14, 'speed': 'slow'},
#  {'color': 'green', 'points': 15, 'speed': 'slow'},
#  {'color': 'green', 'points': 16, 'speed': 'slow'},
#  {'color': 'green', 'points': 17, 'speed': 'slow'},
# ...

# %% [markdown]
# ## A list in a dictionary

# %%
# Store information about a pizza being ordered.

pizza = {
 'crust': 'thick',
 'toppings': ['mushrooms', 'extra cheese'],}

 # Summarize the order.
print("You ordered a " + pizza['crust'] + "-crust pizza " +"with the following toppings:")
for topping in pizza['toppings']:
  print("\t" + topping)
# Out:
# You ordered a thick-crust pizza with the following toppings:
# 	mushrooms
# 	extra cheese

# %%
#Example
#favorite_languages.py
favorite_languages = { 'jen': ['python', 'ruby'], 
                      'sarah': ['c'],
                      'edward': ['ruby', 'go'],
                      'phil': ['python', 'haskell'],
                      }
for name, languages in favorite_languages.items():
    print("\n" + name.title() + "'s favorite languages are:")
    for language in languages:
      print("\t" + language.title())
# Out:
# Jen's favorite languages are:
# 	Python
# 	Ruby
#
# Sarah's favorite languages are:
# 	C
#
# Edward's favorite languages are:
# 	Ruby
# 	Go
#
# Phil's favorite languages are:
# 	Python
# 	Haskell

# %%
#Book Example
#many_users.py
users = {'aeinstein': {'first': 'albert',
                       'last': 'einstein',
                       'location': 'princeton',},
          'mcurie': {'first': 'marie',
                     'last': 'curie', 
                     'location': 'paris',},
 }
for username, user_info in users.items():
  print("\nUsername: " + username)
  full_name = user_info['first'] + " " + user_info['last']
  location = user_info['location']
  print("\tFull name: " + full_name.title())
  print("\tLocation: " + location.title())
# Out:
# Username: aeinstein
# 	Full name: Albert Einstein
# 	Location: Princeton
#
# Username: mcurie
# 	Full name: Marie Curie
# 	Location: Paris

# %% [markdown]
# ## Dictionayof Dic

# %%
dicofdic={ 'saylani':
          {'smit':['web','ds','ccna','ai'],
           'health':['opd','ot']},
          'university':
          {"CS":['1st','2nd','3rd','4th'],
           'admin':['fees','timetable','exams']}
          }

# %%
for pk,pv in dicofdic.items():
  if pk == "university":
    for uk,uv in dicofdic[pk].items():
      if uk == 'admin':
        print('exams' in uv)
# the above block of code will check university-> admin -> exams(return true or false)
# Out:
# True

# %%
#replaced dicofdic[pk].items() => pv.items()
for pk,pv in dicofdic.items():
  if pk == "university":
    for uk,uv in pv.items():
      if uk == 'admin':
        print('exams' in uv)
# Out:
# True

# %%
# To Solve book Exercises

# %% [markdown]
# ## While Loop

# %%
#problem
fav_languages=[]
for lang in range(4):
  fav_lang = input("Enter fav lang")
  fav_languages.append(fav_lang)
print(fav_languages)
# Out:
# Enter fav lang
# Enter fav lang
# Enter fav lang
# Enter fav lang
# ['', '', '', '']

# %%
fav_languages=[]
flag=True
while(flag):
  fav_lang = input("Enter fav lang or quit to exxit")
  if fav_lang ='quit':
    flag = False
  else:
    fav_languages.append(fav_lang)
# Out:
#   File "<ipython-input-64-2df745e34787>", line 5
#     if fav_lang='quit':
#                ^
# SyntaxError: invalid syntax
