# %% [markdown]
# ## Function

# %%
age = 80
def fullName():
  fname = input("Enter first name")
  lname = input("Enter last name")
#concept of local and global variables
  global fullname #convert local variable into global variable
  fullname = f"{fname}  {lname}"
  print(fullname, age)
  return fullname,100,4400,[3,4,5]

# %%
fullName()
# Out:
# Enter first namea
# Enter last names
# a  s 80
# ('a  s', 100, 4400, [3, 4, 5])

# %%
fullname
# Out:
# 'sa  ad'

# %%
myfullname = fullName()

# %%
incomeTax()
# Out:
# Enter your Salary100
# Salary =  100
# Tax =  5.0

# %%
# def < function name > <(arguments/parameters)>
def add(N1,N2):
    """This function is made by me"""  # docstring if writtenin the first line of function
  sum1= N1+N2
  return sum1
  """This function is made by me"""  #multi line comment if write at any place with in code

# %%
num1=input()
num2=input()
add(num1,num2)
# Out:
# 5
# 5
# '55'

# %%
#positional Arguments
add(22,23)
# Out:
# 45

# %%
#keyword arguments
add(N1=2,N2=5)
# Out:
# 7

# %%
#positional VS keyword arguments
#we first write positional args before keyword arguments
add(5,N2=8)
# Out:
# 13

# %%
def incomeTax(): #parameter less function
  salary = int(input("Enter your Salary"))
  tax = salary*5/100
  print("Salary = ",salary)
  print("Tax = ",tax)

# %%
salary = int(input("Enter your Salary"))

def incomeTax(salary,tax): #parameterised function
  gross_salary=(tax*(salary/100))
  print("Salary = ",salary)
  print("Tax = ",tax)
  print("Gross salary = ",gross_salary)
# Out:
# 7

# %% [markdown]
# ## Income Tax Calculator
#     === Completed ===    === Working ===

# %%
def incomeTax(salary): #parameterised function
#tax
  tax_amt= calc_tax(salary)
  tax_cal=(tax_amt*(salary/100))  
#commision
  commmission_amt = calc_commission(salary)
  com_cal=(commmission_amt*(salary/100))
#deductions
  deduction = tax_cal
  addons = com_cal
  gross_salary = (salary+addons)-deduction

#printing results
  print("Salary = ",salary)
  print("Tax = ",tax_amt,"%")
  print("Comission = ", commmission_amt,"%")
  print("Deduction = ",deduction)
  print("Add ons = ",addons)
  print("Gross salary = ",gross_salary)

def calc_tax(sal):
  if(sal<=50000):
    tax = 0
  elif (sal>50000 and sal<=100000):
    tax = 7
  elif (sal>100000 and sal<=500000):
    tax = 13
  elif (sal>500000):
    tax = 17
  else:
    print ("Error")
  
  return tax

def calc_commission(sal):
  sales = int(input("Enter No of Sales: "))
  if(sales<=5):
    commission = 0
  elif (sales>5 and sales<=10):
    commission = 5
  elif (sales>10 and sales<=20):
    tax = 10
  elif (sales>20):
    commission = 15
  else:
    print ("Error")
  
  return commission

# %%
#Driver method
salary = int(input("Enter your Salary"))
incomeTax(salary)
# Out:
# Enter your Salary100000
# Enter No of Sales: 25
# Salary =  100000
# Tax =  7 %
# Comission =  15 %
# Deduction =  7000.0
# Add ons =  15000.0
# Gross salary =  108000.0
